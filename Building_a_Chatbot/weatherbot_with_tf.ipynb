# %%
# Ensure TensorFlow 2.x is installed
# !pip install tensorflow

# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.models import Model
import numpy as np
import requests

# %%
questions = [
    "Hi",
    "Hello",
    "Hey",
    "Howdy",
    "What's up?",
    "How are you?",
    "How's it going?",
    "Good morning",
    "Good afternoon",
    "Good evening",
    "Bye",
    "Goodbye",
    "See you later",
    "Farewell",
    "Catch you later",
    "I'm done",
    "Take care",
]

answers = [
    "Hello! How can I assist you?",
    "Hi there! How can I assist you?",
    "Hey! How's it going?",
    "Howdy! What can I do for you?",
    "Not much, how about you?",
    "I'm doing great, thanks for asking! How can I assist you?",
    "All good here! How can I help?",
    "Good morning! How can I assist you?",
    "Good afternoon! How can I assist you?",
    "Good evening! How can I assist you?",
    "Bye! Have a great day!",
    "Goodbye! It was nice talking to you.",
    "See you later! Take care.",
    "Farewell! Hope to see you again soon.",
    "Catch you later! Have a good one.",
    "It was nice talking to you. Goodbye!",
    "Take care! Let me know if you need anything else.",
]

# %%
# Example dataset: A small set of question-answer pairs
#questions = ['How are you?', 'What is your name?', 'What is TensorFlow?', 'Do you like Python?']
#answers = ['I am fine.', 'I am a bot.', 'TensorFlow is a machine learning library.', 'Yes, Python is great!']

# Tokenize the sentences (this is a very simplified approach)
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(questions + answers)
sequences_questions = tokenizer.texts_to_sequences(questions)
sequences_answers = tokenizer.texts_to_sequences(answers)

# Pad the sequences
max_length = max(max(len(seq) for seq in sequences_questions), max(len(seq) for seq in sequences_answers))
padded_questions = tf.keras.preprocessing.sequence.pad_sequences(sequences_questions, maxlen=max_length, padding='post')
padded_answers = tf.keras.preprocessing.sequence.pad_sequences(sequences_answers, maxlen=max_length, padding='post')

# Vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# %%
# Define model parameters
embedding_dim = 256
units = 1024

# Define the encoder model
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(vocab_size, embedding_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(units, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Define the decoder model
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(vocab_size, embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(units, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the seq2seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None)]               0         []
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  embedding (Embedding)       (None, None, 256)            15872     ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, None, 256)            15872     ['input_2[0][0]']
#
#  lstm (LSTM)                 [(None, 1024),               5246976   ['embedding[0][0]']
#                               (None, 1024),
#                               (None, 1024)]
#
#  lstm_1 (LSTM)               [(None, None, 1024),         5246976   ['embedding_1[0][0]',
#                               (None, 1024),                          'lstm[0][1]',
#                               (None, 1024)]                          'lstm[0][2]']
#
#  dense (Dense)               (None, None, 62)             63550     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 10589246 (40.39 MB)
# Trainable params: 10589246 (40.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Prepare decoder input data that just contains the start token and the rest is all 0
# It's a simplified approach, in practice, you would use teacher forcing or another technique
decoder_input_data = np.zeros_like(padded_answers)
decoder_input_data[:, 0] = 1  # Assuming 1 is the start token

# Train the model
model.fit([padded_questions, decoder_input_data], np.expand_dims(padded_answers, -1), batch_size=2, epochs=100)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 5s 44ms/step - loss: 3.4026 - accuracy: 0.3476
# Epoch 2/100
# 9/9 [==============================] - 0s 15ms/step - loss: 2.6943 - accuracy: 0.3957
# Epoch 3/100
# 9/9 [==============================] - 0s 14ms/step - loss: 2.6747 - accuracy: 0.3529
# Epoch 4/100
# 9/9 [==============================] - 0s 20ms/step - loss: 2.5738 - accuracy: 0.4118
# Epoch 5/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.6744 - accuracy: 0.3690
# Epoch 6/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.4636 - accuracy: 0.4064
# Epoch 7/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.4574 - accuracy: 0.4385
# Epoch 8/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.4691 - accuracy: 0.4171
# Epoch 9/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.3966 - accuracy: 0.4118
# Epoch 10/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.3983 - accuracy: 0.4545
# Epoch 11/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.2990 - accuracy: 0.4706
# Epoch 12/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.3097 - accuracy: 0.4064
# Epoch 13/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.2599 - accuracy: 0.4545
# Epoch 14/100
# 9/9 [==============================] - 0s 20ms/step - loss: 2.1844 - accuracy: 0.4332
# Epoch 15/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.3105 - accuracy: 0.4545
# Epoch 16/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.2433 - accuracy: 0.4064
# Epoch 17/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.0894 - accuracy: 0.4492
# Epoch 18/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.1065 - accuracy: 0.4278
# Epoch 19/100
# 9/9 [==============================] - 0s 14ms/step - loss: 2.0107 - accuracy: 0.4813
# Epoch 20/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.1545 - accuracy: 0.4171
# Epoch 21/100
# 9/9 [==============================] - 0s 14ms/step - loss: 2.0505 - accuracy: 0.4652
# Epoch 22/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.9601 - accuracy: 0.4706
# Epoch 23/100
# 9/9 [==============================] - 0s 12ms/step - loss: 2.0645 - accuracy: 0.4225
# Epoch 24/100
# 9/9 [==============================] - 0s 13ms/step - loss: 2.0454 - accuracy: 0.4545
# Epoch 25/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.8797 - accuracy: 0.5187
# Epoch 26/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.7741 - accuracy: 0.5241
# Epoch 27/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.7073 - accuracy: 0.5401
# Epoch 28/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.7876 - accuracy: 0.4813
# Epoch 29/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.7072 - accuracy: 0.4973
# Epoch 30/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.7560 - accuracy: 0.4866
# Epoch 31/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.7229 - accuracy: 0.4492
# Epoch 32/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.6082 - accuracy: 0.5134
# Epoch 33/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.6137 - accuracy: 0.4920
# Epoch 34/100
# 9/9 [==============================] - 0s 17ms/step - loss: 1.5800 - accuracy: 0.5615
# Epoch 35/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.6512 - accuracy: 0.4866
# Epoch 36/100
# 9/9 [==============================] - 0s 15ms/step - loss: 1.4232 - accuracy: 0.5134
# Epoch 37/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.6159 - accuracy: 0.4599
# Epoch 38/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.4239 - accuracy: 0.5348
# Epoch 39/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.5110 - accuracy: 0.4920
# Epoch 40/100
# 9/9 [==============================] - 0s 15ms/step - loss: 1.4250 - accuracy: 0.5668
# Epoch 41/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.4758 - accuracy: 0.5455
# Epoch 42/100
# 9/9 [==============================] - 0s 15ms/step - loss: 1.3471 - accuracy: 0.5241
# Epoch 43/100
# 9/9 [==============================] - 0s 23ms/step - loss: 1.4338 - accuracy: 0.5508
# Epoch 44/100
# 9/9 [==============================] - 0s 17ms/step - loss: 1.5654 - accuracy: 0.4759
# Epoch 45/100
# 9/9 [==============================] - 0s 17ms/step - loss: 1.4047 - accuracy: 0.4866
# Epoch 46/100
# 9/9 [==============================] - 0s 17ms/step - loss: 1.2653 - accuracy: 0.5401
# Epoch 47/100
# 9/9 [==============================] - 0s 19ms/step - loss: 1.4038 - accuracy: 0.5294
# Epoch 48/100
# 9/9 [==============================] - 0s 15ms/step - loss: 1.2552 - accuracy: 0.5027
# Epoch 49/100
# 9/9 [==============================] - 0s 16ms/step - loss: 1.2792 - accuracy: 0.5348
# Epoch 50/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.2730 - accuracy: 0.5401
# Epoch 51/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.2206 - accuracy: 0.5561
# Epoch 52/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.2402 - accuracy: 0.5294
# Epoch 53/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1870 - accuracy: 0.5134
# Epoch 54/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.3729 - accuracy: 0.5401
# Epoch 55/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0801 - accuracy: 0.5561
# Epoch 56/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.4027 - accuracy: 0.5294
# Epoch 57/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.3484 - accuracy: 0.4866
# Epoch 58/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1301 - accuracy: 0.5561
# Epoch 59/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1837 - accuracy: 0.5455
# Epoch 60/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.1506 - accuracy: 0.5348
# Epoch 61/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0777 - accuracy: 0.5989
# Epoch 62/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0655 - accuracy: 0.5561
# Epoch 63/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.1384 - accuracy: 0.5241
# Epoch 64/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.1807 - accuracy: 0.5668
# Epoch 65/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.0662 - accuracy: 0.5882
# Epoch 66/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.2768 - accuracy: 0.4759
# Epoch 67/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9911 - accuracy: 0.5508
# Epoch 68/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9796 - accuracy: 0.5508
# Epoch 69/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1429 - accuracy: 0.5241
# Epoch 70/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.3922 - accuracy: 0.5401
# Epoch 71/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.3208 - accuracy: 0.5187
# Epoch 72/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0444 - accuracy: 0.5775
# Epoch 73/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0107 - accuracy: 0.5348
# Epoch 74/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.8894 - accuracy: 0.6043
# Epoch 75/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0649 - accuracy: 0.5294
# Epoch 76/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.2403 - accuracy: 0.5134
# Epoch 77/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9707 - accuracy: 0.5615
# Epoch 78/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9712 - accuracy: 0.6631
# Epoch 79/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1895 - accuracy: 0.6043
# Epoch 80/100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.0786 - accuracy: 0.6364
# Epoch 81/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.4937 - accuracy: 0.5187
# Epoch 82/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8367 - accuracy: 0.6684
# Epoch 83/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7941 - accuracy: 0.6791
# Epoch 84/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.8663 - accuracy: 0.6524
# Epoch 85/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0679 - accuracy: 0.6203
# Epoch 86/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0809 - accuracy: 0.5882
# Epoch 87/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.9160 - accuracy: 0.5936
# Epoch 88/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.8575 - accuracy: 0.6417
# Epoch 89/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6873 - accuracy: 0.7005
# Epoch 90/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8716 - accuracy: 0.6203
# Epoch 91/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7214 - accuracy: 0.7059
# Epoch 92/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0437 - accuracy: 0.5455
# Epoch 93/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8429 - accuracy: 0.6417
# Epoch 94/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7860 - accuracy: 0.6471
# Epoch 95/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6174 - accuracy: 0.7326
# Epoch 96/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7082 - accuracy: 0.7005
# Epoch 97/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.7180 - accuracy: 0.7005
# Epoch 98/100
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1818 - accuracy: 0.5722
# Epoch 99/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6248 - accuracy: 0.7326
# Epoch 100/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6047 - accuracy: 0.7861

# %%
# Implement the chat function
def preprocess_input_text(input_text):
    sequence = tokenizer.texts_to_sequences([input_text])
    padded_sequence = tf.keras.preprocessing.sequence.pad_sequences(sequence, maxlen=max_length, padding='post')
    return padded_sequence

def generate_response(input_sequence):
    response_sequence = np.zeros((1, max_length))
    response_sequence[0, 0] = 1  # start token
    for i in range(1, max_length):
        prediction = model.predict([input_sequence, response_sequence]).argmax(axis=2)
        response_sequence[0, i] = prediction[0, i-1]
        if prediction[0, i-1] == 2:  # end token
            break
    return response_sequence

def sequence_to_text(sequence):
    return ' '.join(tokenizer.index_word.get(i, '') for i in sequence if i > 2)

def clean_input(user_input):
    cleaned_input = user_input.strip().lower() # Remove leading/trailing spaces and convert to lowercase
    cleaned_input = ''.join(char for char in cleaned_input if char.isalnum() or char.isspace()) # Remove punctuation
    return cleaned_input

def chat_with_bot(input_text):
    input_sequence = preprocess_input_text(input_text)
    response_sequence = generate_response(input_sequence)
    response_text = sequence_to_text(response_sequence[0])
    return response_text

# Function to get weather information using OpenWeatherMap API
def get_weather(location):
    api_key = ""
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    try:
        city_name, state_code = location.split(", ")
        query = f"{city_name},{state_code},US"
    except ValueError:
        query = f"{location},US"
    complete_url = base_url + "appid=" + api_key + "&q=" + query + "&units=imperial"
    response = requests.get(complete_url)
    weather_data = response.json()
    if weather_data['cod'] == 200:
        main = weather_data['main']
        temperature = main['temp']
        humidity = main['humidity']
        weather_description = weather_data['weather'][0]['description']
        return (f"Temperature: {temperature}°F\n"
                f"Humidity: {humidity}%\n"
                f"Description: {weather_description.capitalize()}")
    else:
        return "Sorry, I couldn't find the weather for that location."

# %%
# Introduce the chatbot and its capabilities
print("Hi! My name is WeatherBot, but I go by 🌤🤖.\nI can assist you with basic greetings, answer how I'm doing, say goodbye, and provide current weather information for any city in the US.\nTo get a weather report, just type 'Weather: [city name], [state code].\nFor cities with unique names, simply typing 'Weather: [city name]' works too!")

# Main loop to handle chat input/output
while True:
    user_input = input("> ")
    if clean_input(user_input) in ["bye", "goodbye", "im done"]:
        print("🌤🤖: Goodbye! Have a great day!")
        break
    elif user_input.lower().startswith("weather: "):
        city = user_input.split(" ", 1)[1]
        weather_info = get_weather(city)
        print("🌤🤖:", weather_info)
    else:
        response = chat_with_bot(user_input)
        print("🌤🤖:", response)
# Out:
# Hi! My name is WeatherBot, but I go by 🌤🤖.
# I can assist you with basic greetings, answer how I'm doing, say goodbye, and provide current weather information for any city in the US.
# To get a weather report, just type 'Weather: [city name], [state code].
# For cities with unique names, simply typing 'Weather: [city name]' works too!
# > Hi!
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 🌤🤖: hello
# > Howdy!
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 🌤🤖: howdy
# > How are you?
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 🌤🤖: i'm doing great thanks for asking
# > Weather: Charlottesville
# 🌤🤖: Temperature: 49.59°F
# Humidity: 94%
# Description: Moderate rain
# > Weather: Culpeper, VA
# 🌤🤖: Temperature: 49.08°F
# Humidity: 97%
# Description: Moderate rain
# > Bye!
# 🌤🤖: Goodbye! Have a great day!
